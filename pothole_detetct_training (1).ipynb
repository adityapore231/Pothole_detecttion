# %%
# !pip install ultralytics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 586.5/586.5 kB 16.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 205.1/205.1 kB 22.3 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
Root_dir = '/content/drive/MyDrive/main_dataset'

# %%
import os
from ultralytics import YOLO
model = YOLO("yolov8n.yaml")

results = model.train(data=os.path.join(Root_dir,"config.yaml"),epochs = 70 )
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.Conv                  [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.Conv                  [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.C2f                   [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.Conv                  [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.C2f                   [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.Conv                  [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.C2f                   [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.Conv                  [128, 256, 3, 2]
# ...

# %%
import locale
def getpreferredencoding(do_setlocale = True):
  return "UTF-8"
locale.getpreferredencoding = getpreferredencoding

# %%
# !scp -r runs/detect/train2 '/content/drive/MyDrive/main_dataset'

# %% [markdown]
# For Prediction

# %%
import os
from ultralytics import YOLO
model = YOLO("/content/very_best.pt")
display = model.predict(source = "/content/drone2.mp4",show=True,save = True,show_labels = True,hide_conf = False,conf = 0.2,save_txt = False,save_crop = False,line_thickness = 2, box = True,visualize = False)
# Out:
# WARNING ⚠️ 'hide_conf' is deprecated and will be removed in 'ultralytics 8.2' in the future. Please use 'show_conf' instead.
# WARNING ⚠️ 'line_thickness' is deprecated and will be removed in 'ultralytics 8.2' in the future. Please use 'line_width' instead.
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
#
#
#     WARNING ⚠️ stream/video/webcam/dir predict source will accumulate results in RAM unless `stream=True` is passed,
#     causing potential out-of-memory errors for large sources or long-running streams/videos.
#
#     Usage:
#         results = model(source=..., stream=True)  # generator of Results objects
#         for r in results:
#             boxes = r.boxes  # Boxes object for bbox outputs
#             masks = r.masks  # Masks object for segment masks outputs
#             probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/929) /content/drone2.mp4: 384x640 (no detections), 49.2ms
# ...

# %% [markdown]
# Training and Validation Results

# %%
from IPython.display import display, Image

# %%
Image(filename='/content/runs/detect/train2/val_batch1_labels.jpg', width=600)

# %%
Image(filename='/content/runs/detect/train2/F1_curve.png', width=600)

# %%
Image(filename='/content/runs/detect/train2/PR_curve.png', width=600)

# %%
Image(filename='/content/runs/detect/train2/P_curve.png', width=600)

# %%
Image(filename='/content/runs/detect/train2/R_curve.png', width=600)

# %%
Image(filename='/content/runs/detect/train2/confusion_matrix.png', width=600)

# %%
Image(filename='/content/runs/detect/train2/results.png', width=600)

# %%
Image(filename='/content/runs/detect/train2/labels_correlogram.jpg', width=600)

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train2/weights/best.pt conf=0.25 source=/content/drive/MyDrive/main_dataset/test/images
# Out:
# Ultralytics YOLOv8.0.87 🚀 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/67 /content/drive/MyDrive/main_dataset/test/images/img-105_jpg.rf.3fe9dff3d1631e79ecb480ff403bcb86.jpg: 640x640 (no detections), 7.3ms
# image 2/67 /content/drive/MyDrive/main_dataset/test/images/img-107_jpg.rf.2e40485785f6e5e2efec404301b235c2.jpg: 640x640 1 pothole, 7.2ms
# image 3/67 /content/drive/MyDrive/main_dataset/test/images/img-146_jpg.rf.61be25b3053a51f622a244980545df2b.jpg: 640x640 1 pothole, 7.2ms
# image 4/67 /content/drive/MyDrive/main_dataset/test/images/img-161_jpg.rf.211541e7178a4a93ec0680f26b905427.jpg: 640x640 2 potholes, 7.1ms
# image 5/67 /content/drive/MyDrive/main_dataset/test/images/img-168_jpg.rf.af3590e07b06b43e91fa53990ff94af3.jpg: 640x640 2 potholes, 7.2ms
# ...

# %%
model = YOLO('/content/best (1).pt')
model.predict(source='/content/WhatsApp Video 2023-04-30 at 13.48.42.mp4', conf=0.25)
# Out:
# image 1/1 /content/WhatsApp Image 2023-04-25 at 22.13.55 (1).jpeg: 640x480 1 pothole, 8.2ms
# Speed: 0.5ms preprocess, 8.2ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)

# %%
#Self Captured image testing
Image(filename='/content/runs/detect/predict8/img-82_jpg.rf.851a545b1b004e7303844e4779d3272c.jpg', width=600)
